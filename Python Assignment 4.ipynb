# %% [markdown]
# 1.1 Write a Python Program(with class concepts) to find the area of the triangle using the below
# formula.
# area = (s*(s-a)*(s-b)*(s-c)) ***
#  0.5
# Function to take the length of the sides of triangle from user should be defined in the parent
# class and function to calculate the area should be defined in subclass.

# %%
class triangle:                   ##Parent Class
  def __init__(self,a,b,c):
    self.a=a
    self.b=b
    self.c=c
class calculate(triangle):    ## Child Class
  def area(self):
    s=(self.a+self.b+self.c)/2
    area=(s*(s-self.a)*(s-self.b)*(s-self.c))**0.5
    return (area)

# %%
tr=calculate(10,10,10)

# %%
print(f'Area:{tr.area():.2f}')
# Out:
# Area:43.30

# %% [markdown]
# 1.2 Write a function filter_long_words() that takes a list of words and an integer n and returns
# the list of words that are longer than n.

# %%
lst=['My','Name','is','Akash','We','Are','Learning','Python']

def filter_long_words(words,n):
  a=[]
  for word in words:
    if len(word)>n:
      a.append(word)
  return a 

filter_long_words(lst,4)
# Out:
# ['Akash', 'Learning', 'Python']

# %% [markdown]
# 2.1 Write a Python program using function concept that maps list of words into a list of integers
# representing the lengths of the corresponding words.

# %%
lst=['My','Name','is','Akash','We','Are','Learning','Python']

def word_length(words):
  a=[]
  for word in words:
    a.append(len(word))
  return a 

word_length(lst)
# Out:
# [2, 4, 2, 5, 2, 3, 8, 6]

# %% [markdown]
# 2.2 Write a Python function which takes a character (i.e. a string of length 1) and returns True if
# it is a vowel, False otherwise.

# %%
vowel=['a','e','i','o','u'] # List of Vowels

def is_vowel(char):
  if char in vowel:
    return True
  else:
    return False

char=input("Enter a character: ")
is_vowel(char[0])        # Passing first character only
# Out:
# Enter a character: a
# True
