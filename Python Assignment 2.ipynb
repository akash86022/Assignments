# %% [markdown]
# 1. Create the below pattern using nested for loop in Python.

# %%
stars=int(input('Enter number of Stars to Print:'))
for i in range (1):
  for i in range(stars):
    print('*'*i)
  for i in range(stars):
    print('*'*(stars-i))
# Out:
# Enter number of Stars to Print:5
#
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
word=input('Enter word:')
output= word[::-1]
print(output)
# Out:
# Enter word:Ineuron
# noruenI
